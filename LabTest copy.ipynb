# %%
print("")

# %%
from pathlib import Path
import numpy as np  
import pandas as pd

#Create a data folder for the files generated by this notebook.
DATA_DIR = Path("data")
DATA_DIR.mkdir(exist_ok=True)

print(f"Data folder is ready: {DATA_DIR.resolve()}")
# Out:
# Data folder is ready: C:\Users\User\Documents\GitHub\AI-and-ML-Laboratory\data

# %%
pickle_path = DATA_DIR / "all_pages.pkl"

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import pickle
import time

search_bases = [
    "https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home",
    "https://www.rottentomatoes.com/browse/movies_at_home/affiliates:netflix",
    "https://www.rottentomatoes.com/browse/movies_at_home/affiliates:apple-tv-plus",
]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36"
}

all_series_urls = []
count_error = 0

for base_url in search_bases:
    for page in range(1, 12):  # páginas 1 a 11
        url = f"{base_url}?page={page}"
        # print(f"Scrapeando página {page}: {url}")

        resp = requests.get(url, headers=headers, timeout=10)

        
        if resp.status_code != 200:
            count_error += 1
            ##### Error if the page has not been created
            print(f"Error en página {page} de {base_url}: HTTP {resp.status_code}") 
            #print(count_error)
            continue # If the error happens, continue with next page

        soup = BeautifulSoup(resp.content, "html.parser")

        for a in soup.find_all("a", href=True):
            full_url = urljoin(url, a["href"])

            if "rottentomatoes.com/tv/" in full_url:
                all_series_urls.append(full_url)
            elif"rottentomatoes.com/m/" in full_url:
                all_series_urls.append(full_url)

        time.sleep(1)  # pausa pequeña para no saturar la página

# Quitar duplicados
all_series_urls = list(dict.fromkeys(all_series_urls))


print(f"\nTotal de series encontradas: {len(all_series_urls)}")
for u in all_series_urls:
    print(u)

with open(DATA_DIR / "all_pages.pkl", "wb") as f:
    pickle.dump(all_series_urls, f)
# Out:
# Error en página 5 de https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home: HTTP 404
# Error en página 6 de https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home: HTTP 404
# Error en página 7 de https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home: HTTP 404
# Error en página 8 de https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home: HTTP 404
# Error en página 9 de https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home: HTTP 404
# Error en página 10 de https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home: HTTP 404
# Error en página 11 de https://www.rottentomatoes.com/browse/movies_at_home/affiliates:fandango-at-home: HTTP 404
#
# Total de series encontradas: 348
# https://www.rottentomatoes.com/m/obsession_2025
# https://www.rottentomatoes.com/m/is_god_is
# https://www.rottentomatoes.com/m/tuner
# https://www.rottentomatoes.com/tv/spider_noir/s01
# https://www.rottentomatoes.com/tv/summerwater/s01
# https://www.rottentomatoes.com/tv/rick_and_morty/s09
# https://www.rottentomatoes.com/tv/star_city/s01
# https://www.rottentomatoes.com/tv/the_four_seasons_2025/s02
# https://www.rottentomatoes.com/tv/a_good_girls_guide_to_murder/s02
# https://www.rottentomatoes.com/tv/deli_boys/s02
# https://www.rottentomatoes.com/tv/world_war_ii_with_tom_hanks/s01
# https://www.rottentomatoes.com/tv/criminal_minds/s19
# https://www.rottentomatoes.com/tv/calabasas_confidential/s01
# https://www.rottentomatoes.com/tv/the_boroughs/s01
# https://www.rottentomatoes.com/tv/the_boys_2019/s05
# https://www.rottentomatoes.com/tv/maximum_pleasure_guaranteed/s01
# https://www.rottentomatoes.com/tv/off_campus/s01
# https://www.rottentomatoes.com/tv/widows_bay/s01
# https://www.rottentomatoes.com/tv/legends_2026/s01
# https://www.rottentomatoes.com/tv/nemesis_2026/s01
# https://www.rottentomatoes.com/tv/rivals_2024/s02
# https://www.rottentomatoes.com/m/nobu
# https://www.rottentomatoes.com/m/lee_cronins_the_mummy
# https://www.rottentomatoes.com/m/normal_2025
# https://www.rottentomatoes.com/m/the_super_mario_galaxy_movie
# https://www.rottentomatoes.com/m/mother_mary
# https://www.rottentomatoes.com/m/wasteman
# https://www.rottentomatoes.com/m/mile_end_kicks
# https://www.rottentomatoes.com/m/miroirs_no_3
# https://www.rottentomatoes.com/m/to_love_a_narcissist
# https://www.rottentomatoes.com/m/monkeys_magic_merry_go_round
# https://www.rottentomatoes.com/m/sight_unseen_2025
# https://www.rottentomatoes.com/m/buzzheart
# https://www.rottentomatoes.com/m/sick_puppy
# https://www.rottentomatoes.com/m/reckless_2026
# https://www.rottentomatoes.com/m/giant_2025
# https://www.rottentomatoes.com/m/project_hail_mary
# https://www.rottentomatoes.com/m/send_help
# https://www.rottentomatoes.com/m/the_drama
# https://www.rottentomatoes.com/m/wuthering_heights_2026
# https://www.rottentomatoes.com/m/marty_supreme
# https://www.rottentomatoes.com/m/goat_2026
# https://www.rottentomatoes.com/m/the_bride_2026
# https://www.rottentomatoes.com/m/we_bury_the_dead
# https://www.rottentomatoes.com/m/the_christophers
# https://www.rottentomatoes.com/m/lurker
# https://www.rottentomatoes.com/m/hoppers
# https://www.rottentomatoes.com/m/good_luck_have_fun_dont_die
# https://www.rottentomatoes.com/m/the_housemaid_2025
# https://www.rottentomatoes.com/m/ready_or_not_2_here_i_come
# https://www.rottentomatoes.com/m/bugonia
# https://www.rottentomatoes.com/m/merrily_we_roll_along
# https://www.rottentomatoes.com/m/good_boy_2025
# https://www.rottentomatoes.com/m/nope
# https://www.rottentomatoes.com/m/mortal_kombat_2021
# https://www.rottentomatoes.com/m/pillion
# https://www.rottentomatoes.com/m/28_years_later_the_bone_temple
# https://www.rottentomatoes.com/m/star_wars_the_rise_of_skywalker
# https://www.rottentomatoes.com/m/faces_of_death_2026
# https://www.rottentomatoes.com/m/black_phone_2
# https://www.rottentomatoes.com/m/the_devil_wears_prada
# https://www.rottentomatoes.com/m/weapons
# https://www.rottentomatoes.com/m/the_running_man_2025
# https://www.rottentomatoes.com/m/sinners_2025
# https://www.rottentomatoes.com/m/they_will_kill_you
# https://www.rottentomatoes.com/m/you_me_and_tuscany
# https://www.rottentomatoes.com/m/undertone
# https://www.rottentomatoes.com/m/star_wars_the_last_jedi
# https://www.rottentomatoes.com/m/one_battle_after_another
# https://www.rottentomatoes.com/m/greenland
# https://www.rottentomatoes.com/m/beast_2026
# https://www.rottentomatoes.com/m/nuremberg_2025
# https://www.rottentomatoes.com/m/top_gun
# https://www.rottentomatoes.com/m/mercy_2026
# https://www.rottentomatoes.com/m/interstellar_2014
# https://www.rottentomatoes.com/m/the_ministry_of_ungentlemanly_warfare
# https://www.rottentomatoes.com/m/rental_family
# https://www.rottentomatoes.com/m/colleen_hoovers_regretting_you
# https://www.rottentomatoes.com/m/oddity
# https://www.rottentomatoes.com/m/avatar_fire_and_ash
# https://www.rottentomatoes.com/m/a_great_awakening
# https://www.rottentomatoes.com/m/dracula_2025_2
# https://www.rottentomatoes.com/m/if_i_had_legs_id_kick_you
# https://www.rottentomatoes.com/m/the_long_walk_2025
# https://www.rottentomatoes.com/m/how_to_make_a_killing_2026
# https://www.rottentomatoes.com/m/top_gun_maverick
# https://www.rottentomatoes.com/m/eternity_2025
# https://www.rottentomatoes.com/m/is_this_thing_on
# https://www.rottentomatoes.com/m/companion_2025
# https://www.rottentomatoes.com/m/solo_a_star_wars_story
# https://www.rottentomatoes.com/m/dust_bunny
# https://www.rottentomatoes.com/m/hamnet
# https://www.rottentomatoes.com/m/shrek
# https://www.rottentomatoes.com/m/gloria_2012
# https://www.rottentomatoes.com/m/shelter_2026
# https://www.rottentomatoes.com/m/scream_7
# https://www.rottentomatoes.com/m/anaconda_2025
# https://www.rottentomatoes.com/m/whistle_2025
# https://www.rottentomatoes.com/m/star_wars_episode_vii_the_force_awakens
# https://www.rottentomatoes.com/m/suburban_fury
# https://www.rottentomatoes.com/m/hallow_road
# https://www.rottentomatoes.com/m/solo_mio
# https://www.rottentomatoes.com/m/superman_2025
# https://www.rottentomatoes.com/m/relay
# https://www.rottentomatoes.com/m/forbidden_fruits_2026
# https://www.rottentomatoes.com/m/together_2025
# https://www.rottentomatoes.com/m/rogue_one_a_star_wars_story
# https://www.rottentomatoes.com/m/the_super_mario_bros_movie
# https://www.rottentomatoes.com/m/reminders_of_him
# https://www.rottentomatoes.com/m/primate_2025
# https://www.rottentomatoes.com/m/trap_2024
# https://www.rottentomatoes.com/m/drivers_ed
# https://www.rottentomatoes.com/m/predator_badlands
# https://www.rottentomatoes.com/m/cold_storage_2026
# https://www.rottentomatoes.com/m/ready_or_not_2019
# https://www.rottentomatoes.com/m/him_2025_2
# https://www.rottentomatoes.com/m/f1_the_movie
# https://www.rottentomatoes.com/m/return_to_silent_hill
# https://www.rottentomatoes.com/m/good_fortune
# https://www.rottentomatoes.com/m/bring_her_back
# https://www.rottentomatoes.com/m/novocaine_2025
# https://www.rottentomatoes.com/m/the_life_of_chuck
# https://www.rottentomatoes.com/m/kingdom_of_heaven
# https://www.rottentomatoes.com/m/avengers_endgame
# https://www.rottentomatoes.com/m/hereditary
# https://www.rottentomatoes.com/m/the_batman
# https://www.rottentomatoes.com/m/five_nights_at_freddys_2
# https://www.rottentomatoes.com/m/man_on_fire
# https://www.rottentomatoes.com/m/the_testament_of_ann_lee
# https://www.rottentomatoes.com/m/troy
# https://www.rottentomatoes.com/m/past_lives
# https://www.rottentomatoes.com/m/the_substance
# https://www.rottentomatoes.com/m/blackberry
# https://www.rottentomatoes.com/m/wanda_sykes_legacy
# https://www.rottentomatoes.com/m/ladies_first_2026
# https://www.rottentomatoes.com/m/remarkably_bright_creatures
# https://www.rottentomatoes.com/m/the_perfect_neighbor_2025
# https://www.rottentomatoes.com/m/apex_2026
# https://www.rottentomatoes.com/m/the_crash_2026
# https://www.rottentomatoes.com/m/swapped_2026
# https://www.rottentomatoes.com/m/war_machine
# https://www.rottentomatoes.com/m/train_dreams
# https://www.rottentomatoes.com/m/marty_life_is_short
# https://www.rottentomatoes.com/m/killer_joe
# https://www.rottentomatoes.com/m/the_rip
# https://www.rottentomatoes.com/m/peaky_blinders_the_immortal_man
# https://www.rottentomatoes.com/m/and_so_it_goes
# https://www.rottentomatoes.com/m/the_roast_of_kevin_hart
# https://www.rottentomatoes.com/m/wake_up_dead_man_a_knives_out_mystery
# https://www.rottentomatoes.com/m/people_we_meet_on_vacation
# https://www.rottentomatoes.com/m/hit_man_2023
# https://www.rottentomatoes.com/m/je_mappelle_agneta
# https://www.rottentomatoes.com/m/dhurandhar
# https://www.rottentomatoes.com/m/thrash
# https://www.rottentomatoes.com/m/28_years_later
# https://www.rottentomatoes.com/m/his_house
# https://www.rottentomatoes.com/m/frankenstein_2025
# https://www.rottentomatoes.com/m/a_house_of_dynamite
# https://www.rottentomatoes.com/m/fifty_shades_of_grey
# https://www.rottentomatoes.com/m/cover_up_2025
# https://www.rottentomatoes.com/m/jurassic_world_rebirth
# https://www.rottentomatoes.com/m/it_ends_with_us
# https://www.rottentomatoes.com/m/mothers_day_2016
# https://www.rottentomatoes.com/m/safe_haven
# https://www.rottentomatoes.com/m/cleaner
# https://www.rottentomatoes.com/m/the_woman_in_cabin_10
# https://www.rottentomatoes.com/m/green_book
# https://www.rottentomatoes.com/m/gladiator_ii
# https://www.rottentomatoes.com/m/1071806-independence_day
# https://www.rottentomatoes.com/m/roommates_2026
# https://www.rottentomatoes.com/m/caught_stealing
# https://www.rottentomatoes.com/m/under_the_shadow
# https://www.rottentomatoes.com/m/kpop_demon_hunters
# https://www.rottentomatoes.com/m/the_hunger_games_the_ballad_of_songbirds_and_snakes
# https://www.rottentomatoes.com/m/until_dawn_2025
# https://www.rottentomatoes.com/m/oppenheimer_2023
# https://www.rottentomatoes.com/m/joker_folie_a_deux
# https://www.rottentomatoes.com/m/havoc_2025
# https://www.rottentomatoes.com/m/eden_2024_2
# https://www.rottentomatoes.com/m/once_upon_a_time_in_hollywood
# https://www.rottentomatoes.com/m/nobody_2
# https://www.rottentomatoes.com/m/the_gentlemen
# https://www.rottentomatoes.com/m/bohemian_rhapsody
# https://www.rottentomatoes.com/m/mrs_harris_goes_to_paris
# https://www.rottentomatoes.com/m/jennifers_body
# https://www.rottentomatoes.com/m/the_lost_city
# https://www.rottentomatoes.com/m/the_gray_man_2022
# https://www.rottentomatoes.com/m/whiplash_2014
# https://www.rottentomatoes.com/m/knives_out
# https://www.rottentomatoes.com/m/spider_man_into_the_spider_verse
# https://www.rottentomatoes.com/m/the_creator_2023
# https://www.rottentomatoes.com/m/schindlers_list
# https://www.rottentomatoes.com/m/fight_club
# https://www.rottentomatoes.com/m/host_2020
# https://www.rottentomatoes.com/m/kraven_the_hunter
# https://www.rottentomatoes.com/m/the_thursday_murder_club
# https://www.rottentomatoes.com/m/leave_the_world_behind_2023
# https://www.rottentomatoes.com/m/how_to_train_your_dragon_2025
# https://www.rottentomatoes.com/m/sicario_2015
# https://www.rottentomatoes.com/m/my_dearest_assassin
# https://www.rottentomatoes.com/m/civil_war_2024
# https://www.rottentomatoes.com/m/the_electric_state
# https://www.rottentomatoes.com/m/along_for_the_ride_2022
# https://www.rottentomatoes.com/m/the_northman
# https://www.rottentomatoes.com/m/warcraft
# https://www.rottentomatoes.com/m/spotlight_2015
# https://www.rottentomatoes.com/m/uncut_gems
# https://www.rottentomatoes.com/m/fifth_element
# https://www.rottentomatoes.com/m/honey_dont
# https://www.rottentomatoes.com/m/striking_distance
# https://www.rottentomatoes.com/m/dont_breathe_2016
# https://www.rottentomatoes.com/m/blue_moon_2025
# https://www.rottentomatoes.com/m/burn_after_reading
# https://www.rottentomatoes.com/m/365_days_2020
# https://www.rottentomatoes.com/m/upgrade_2018
# https://www.rottentomatoes.com/m/the_truth_and_tragedy_of_moriah_wilson
# https://www.rottentomatoes.com/m/creep_2014
# https://www.rottentomatoes.com/m/jay_kelly
# https://www.rottentomatoes.com/m/the_power_of_the_dog
# https://www.rottentomatoes.com/m/catch_me_if_you_can
# https://www.rottentomatoes.com/m/the_ritual_2017
# https://www.rottentomatoes.com/m/lucy_2014
# https://www.rottentomatoes.com/m/love-and-other-drugs
# https://www.rottentomatoes.com/m/the_emoji_movie
# https://www.rottentomatoes.com/m/passion_of_the_christ
# https://www.rottentomatoes.com/m/trap_house_2025
# https://www.rottentomatoes.com/m/argo_2012
# https://www.rottentomatoes.com/m/wild_mountain_thyme
# https://www.rottentomatoes.com/m/dont_look_up_2021
# https://www.rottentomatoes.com/m/incantation
# https://www.rottentomatoes.com/m/carry_on
# https://www.rottentomatoes.com/m/perfect_days_2023
# https://www.rottentomatoes.com/m/catch_and_release
# https://www.rottentomatoes.com/m/are_you_there_god_its_me_margaret
# https://www.rottentomatoes.com/m/the_killer_2023
# https://www.rottentomatoes.com/m/a_big_bold_beautiful_journey
# https://www.rottentomatoes.com/m/babylon_2022
# https://www.rottentomatoes.com/m/ex_machina
# https://www.rottentomatoes.com/m/1070992-primal_fear
# https://www.rottentomatoes.com/m/under_the_silver_lake
# https://www.rottentomatoes.com/m/triangle_of_sadness
# https://www.rottentomatoes.com/m/the_green_knight
# https://www.rottentomatoes.com/m/spiderman_2
# https://www.rottentomatoes.com/m/friendship_2024
# https://www.rottentomatoes.com/m/rebel_ridge
# https://www.rottentomatoes.com/m/its_whats_inside
# https://www.rottentomatoes.com/m/the_best_you_can
# https://www.rottentomatoes.com/m/the_irishman
# https://www.rottentomatoes.com/m/den_of_thieves
# https://www.rottentomatoes.com/m/elvis
# https://www.rottentomatoes.com/m/hell_or_high_water
# https://www.rottentomatoes.com/m/pulp_fiction
# https://www.rottentomatoes.com/m/the_iron_claw_2023
# https://www.rottentomatoes.com/m/spiderman
# https://www.rottentomatoes.com/m/twilight
# https://www.rottentomatoes.com/m/redeeming_love
# https://www.rottentomatoes.com/m/rrr
# https://www.rottentomatoes.com/m/i_came_by
# https://www.rottentomatoes.com/m/lady_bird
# https://www.rottentomatoes.com/m/outcome
# https://www.rottentomatoes.com/m/highest_2_lowest
# https://www.rottentomatoes.com/m/the_gorge
# https://www.rottentomatoes.com/m/the_lost_bus
# https://www.rottentomatoes.com/m/fountain_of_youth_2025
# https://www.rottentomatoes.com/m/killers_of_the_flower_moon
# https://www.rottentomatoes.com/m/greyhound
# https://www.rottentomatoes.com/m/come_see_me_in_the_good_light
# https://www.rottentomatoes.com/m/still_a_michael_j_fox_movie
# https://www.rottentomatoes.com/m/coda_2021
# https://www.rottentomatoes.com/m/wolfwalkers
# https://www.rottentomatoes.com/m/wolfs
# https://www.rottentomatoes.com/m/napoleon_2023
# https://www.rottentomatoes.com/m/argylle
# https://www.rottentomatoes.com/m/the_family_plan
# https://www.rottentomatoes.com/m/all_of_you_2024
# https://www.rottentomatoes.com/m/downwind
# https://www.rottentomatoes.com/m/finch
# https://www.rottentomatoes.com/m/tetris
# https://www.rottentomatoes.com/m/fly_me_to_the_moon_2024
# https://www.rottentomatoes.com/m/echo_valley
# https://www.rottentomatoes.com/m/sharper
# https://www.rottentomatoes.com/m/ghosted_2023
# https://www.rottentomatoes.com/m/blitz
# https://www.rottentomatoes.com/m/swan_song_2021_2
# https://www.rottentomatoes.com/m/palmer
# https://www.rottentomatoes.com/m/the_family_plan_2
# https://www.rottentomatoes.com/m/luck_2022
# https://www.rottentomatoes.com/m/the_instigators
# https://www.rottentomatoes.com/m/cherry_2021
# https://www.rottentomatoes.com/m/flora_and_son
# https://www.rottentomatoes.com/m/the_banker_2020
# https://www.rottentomatoes.com/m/you_hurt_my_feelings_2023
# https://www.rottentomatoes.com/m/causeway
# https://www.rottentomatoes.com/m/the_greatest_beer_run_ever
# https://www.rottentomatoes.com/m/the_tragedy_of_macbeth_2021
# https://www.rottentomatoes.com/m/emancipation_2022
# https://www.rottentomatoes.com/m/fingernails
# https://www.rottentomatoes.com/m/bread_and_roses_2023
# https://www.rottentomatoes.com/m/cha_cha_real_smooth
# https://www.rottentomatoes.com/m/on_the_rocks_2020
# https://www.rottentomatoes.com/m/come_from_away
# https://www.rottentomatoes.com/m/the_pigeon_tunnel
# https://www.rottentomatoes.com/m/mad_heidi
# https://www.rottentomatoes.com/m/raymond_and_ray
# https://www.rottentomatoes.com/m/stiller_and_meara_nothing_is_lost
# https://www.rottentomatoes.com/m/the_bloody_hundredth
# https://www.rottentomatoes.com/m/fancy_dance_2023
# https://www.rottentomatoes.com/m/fireball_visitors_from_darker_worlds
# https://www.rottentomatoes.com/m/deaf_president_now
# https://www.rottentomatoes.com/m/boys_state
# https://www.rottentomatoes.com/m/billie_eilish_the_worlds_a_little_blurry
# https://www.rottentomatoes.com/m/spirited
# https://www.rottentomatoes.com/m/when_i_consume_you
# https://www.rottentomatoes.com/m/hala
# https://www.rottentomatoes.com/m/the_velveteen_rabbit
# https://www.rottentomatoes.com/m/the_beanie_bubble
# https://www.rottentomatoes.com/m/the_last_of_the_sea_women
# https://www.rottentomatoes.com/m/dads
# https://www.rottentomatoes.com/m/the_boy_the_mole_the_fox_and_the_horse
# https://www.rottentomatoes.com/m/girls_state
# https://www.rottentomatoes.com/m/hannah_waddingham_home_for_christmas
# https://www.rottentomatoes.com/m/the_elephant_queen
# https://www.rottentomatoes.com/m/selena_gomez_my_mind_and_me
# https://www.rottentomatoes.com/m/the_last_autumn
# https://www.rottentomatoes.com/m/the_velvet_underground_2021
# https://www.rottentomatoes.com/m/the_sky_is_everywhere
# https://www.rottentomatoes.com/m/the_first_snow_of_fraggle_rock
# https://www.rottentomatoes.com/m/stephen_curry_underrated
# https://www.rottentomatoes.com/m/all_eyes
# https://www.rottentomatoes.com/m/wonderwell
# https://www.rottentomatoes.com/m/bono_stories_of_surrender
# https://www.rottentomatoes.com/m/here_we_are_notes_for_living_on_planet_earth
# https://www.rottentomatoes.com/m/with_this_light
# https://www.rottentomatoes.com/m/sidney_2022
# https://www.rottentomatoes.com/m/snoopy_presents_a_summer_musical
# https://www.rottentomatoes.com/m/the_furry_fortune
# https://www.rottentomatoes.com/m/beastie_boys_story
# https://www.rottentomatoes.com/m/fathom_2021
# https://www.rottentomatoes.com/m/barbie_nation_an_unauthorized_tour
# https://www.rottentomatoes.com/m/the_crusades_2023
# https://www.rottentomatoes.com/m/snoopy_presents_welcome_home_franklin
# https://www.rottentomatoes.com/m/louis_armstrongs_black_and_blues
# https://www.rottentomatoes.com/m/lulu_is_a_rhinoceros
# https://www.rottentomatoes.com/m/snoopy_presents_one_of_a_kind_marcie
# https://www.rottentomatoes.com/m/lucys_school
# https://www.rottentomatoes.com/m/its_the_easter_beagle_charlie_brown
# https://www.rottentomatoes.com/m/mariah_careys_magical_christmas_special
# https://www.rottentomatoes.com/m/snoopy_presents_for_auld_lang_syne

# %% [markdown]
# # Function to take many URLs

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import pickle
import time

url_search = [
    "https://www.rottentomatoes.com/browse/tv_series_browse/?page="
]

def generate_search_page_urls(base_urls, start=1, end=4):
    """Genera una lista de URLs de páginas de búsqueda a partir de una lista base."""
    return [f"{base}{page}" for base in base_urls for page in range(start, end + 1)]


def collect_series_urls_from_search_pages(page_urls, delay=1):
    """Extrae todas las URLs de series de una lista de páginas de búsqueda."""
    all_series_urls = []

    for page_url in page_urls:
        resp = requests.get(page_url, headers=headers, timeout=10)
        if resp.status_code != 200:
            print(f"Error en página {page_url}: HTTP {resp.status_code}")
            continue

        soup = BeautifulSoup(resp.content, "html.parser")
        for a in soup.find_all("a", href=True):
            full_url = urljoin(page_url, a["href"])
            if "/tv/" in full_url:
                all_series_urls.append(full_url)
            elif "rottentomatoes.com/tv/" in full_url:
                all_series_urls.append(full_url)

        time.sleep(delay)

    return list(dict.fromkeys(all_series_urls))


# Generar las URLs de todas las páginas de búsqueda y luego extraer las URLs de series.
search_page_urls = generate_search_page_urls(url_search, start=1, end=4)
print(f"Se generaron {len(search_page_urls)} URLs de búsqueda")

all_series_urls = collect_series_urls_from_search_pages(search_page_urls, delay=1)
print(f"\nTotal de series encontradas: {len(all_series_urls)}")
for u in all_series_urls:
    print(u)

with open(DATA_DIR / "series_urls_pages.pkl", "wb") as f:
    pickle.dump(all_series_urls, f)
# Out:
# Se generaron 4 URLs de búsqueda
#
# Total de series encontradas: 130
# https://www.rottentomatoes.com/tv/spider_noir/s01
# https://www.rottentomatoes.com/tv/summerwater/s01
# https://www.rottentomatoes.com/tv/rick_and_morty/s09
# https://www.rottentomatoes.com/tv/star_city/s01
# https://www.rottentomatoes.com/tv/the_four_seasons_2025/s02
# https://www.rottentomatoes.com/tv/a_good_girls_guide_to_murder/s02
# https://www.rottentomatoes.com/tv/deli_boys/s02
# https://www.rottentomatoes.com/tv/world_war_ii_with_tom_hanks/s01
# https://www.rottentomatoes.com/tv/criminal_minds/s19
# https://www.rottentomatoes.com/tv/calabasas_confidential/s01
# https://www.rottentomatoes.com/tv/the_boroughs/s01
# https://www.rottentomatoes.com/tv/the_boys_2019/s05
# https://www.rottentomatoes.com/tv/maximum_pleasure_guaranteed/s01
# https://www.rottentomatoes.com/tv/off_campus/s01
# https://www.rottentomatoes.com/tv/widows_bay/s01
# https://www.rottentomatoes.com/tv/legends_2026/s01
# https://www.rottentomatoes.com/tv/nemesis_2026/s01
# https://www.rottentomatoes.com/tv/rivals_2024/s02
# https://www.rottentomatoes.com/tv/the_boys_2019
# https://www.rottentomatoes.com/tv/off_campus
# https://www.rottentomatoes.com/tv/nemesis_2026
# https://www.rottentomatoes.com/tv/the_boroughs
# https://www.rottentomatoes.com/tv/legends_2026
# https://www.rottentomatoes.com/tv/maximum_pleasure_guaranteed
# https://www.rottentomatoes.com/tv/widows_bay
# https://www.rottentomatoes.com/tv/from
# https://www.rottentomatoes.com/tv/dutton_ranch
# https://www.rottentomatoes.com/tv/beef
# https://www.rottentomatoes.com/tv/rivals_2024
# https://www.rottentomatoes.com/tv/the_chestnut_man
# https://www.rottentomatoes.com/tv/berlin_2023
# https://www.rottentomatoes.com/tv/youre_killing_me
# https://www.rottentomatoes.com/tv/spider_noir
# https://www.rottentomatoes.com/tv/euphoria
# https://www.rottentomatoes.com/tv/devil_may_cry
# https://www.rottentomatoes.com/tv/margos_got_money_troubles
# https://www.rottentomatoes.com/tv/lord_of_the_flies
# https://www.rottentomatoes.com/tv/good_omens
# https://www.rottentomatoes.com/tv/half_man
# https://www.rottentomatoes.com/tv/the_dark_wizard
# https://www.rottentomatoes.com/tv/your_friends_and_neighbors
# https://www.rottentomatoes.com/tv/man_on_fire
# https://www.rottentomatoes.com/tv/kylie
# https://www.rottentomatoes.com/tv/star_wars_maul_shadow_lord
# https://www.rottentomatoes.com/tv/the_terror_2026
# https://www.rottentomatoes.com/tv/citadel
# https://www.rottentomatoes.com/tv/the_yogurt_shop_murders
# https://www.rottentomatoes.com/tv/rooster
# https://www.rottentomatoes.com/tv/mating_season
# https://www.rottentomatoes.com/tv/the_other_bennet_sister
# https://www.rottentomatoes.com/tv/rick_and_morty
# https://www.rottentomatoes.com/tv/marshals
# https://www.rottentomatoes.com/tv/something_very_bad_is_going_to_happen
# https://www.rottentomatoes.com/tv/the_white_lotus
# https://www.rottentomatoes.com/tv/for_all_mankind
# https://www.rottentomatoes.com/tv/amadeus
# https://www.rottentomatoes.com/tv/mia
# https://www.rottentomatoes.com/tv/sapne_vs_everyone
# https://www.rottentomatoes.com/tv/daredevil_born_again
# https://www.rottentomatoes.com/tv/its_not_like_that
# https://www.rottentomatoes.com/tv/the_testaments
# https://www.rottentomatoes.com/tv/the_mandalorian
# https://www.rottentomatoes.com/tv/skymed
# https://www.rottentomatoes.com/tv/hacks
# https://www.rottentomatoes.com/tv/if_wishes_could_kill
# https://www.rottentomatoes.com/tv/imperfect_women
# https://www.rottentomatoes.com/tv/stranger_things
# https://www.rottentomatoes.com/tv/pluribus
# https://www.rottentomatoes.com/tv/the_pitt
# https://www.rottentomatoes.com/tv/fire_country
# https://www.rottentomatoes.com/tv/unchosen
# https://www.rottentomatoes.com/tv/the_chi
# https://www.rottentomatoes.com/tv/the_madison
# https://www.rottentomatoes.com/tv/desi_bling
# https://www.rottentomatoes.com/tv/how_to_get_to_heaven_from_belfast
# https://www.rottentomatoes.com/tv/the_wonderfools
# https://www.rottentomatoes.com/tv/invincible
# https://www.rottentomatoes.com/tv/dtf_st_louis
# https://www.rottentomatoes.com/tv/everyone_is_doing_great
# https://www.rottentomatoes.com/tv/jack_ryan
# https://www.rottentomatoes.com/tv/one_piece_2023
# https://www.rottentomatoes.com/tv/the_night_manager
# https://www.rottentomatoes.com/tv/marvels_the_punisher
# https://www.rottentomatoes.com/tv/true_detective
# https://www.rottentomatoes.com/tv/stranger_things_tales_from_85
# https://www.rottentomatoes.com/tv/outlander
# https://www.rottentomatoes.com/tv/should_i_marry_a_murderer
# https://www.rottentomatoes.com/tv/paradise_2025
# https://www.rottentomatoes.com/tv/the_cleaning_lady
# https://www.rottentomatoes.com/tv/big_mistakes
# https://www.rottentomatoes.com/tv/gen_v
# https://www.rottentomatoes.com/tv/game_of_thrones
# https://www.rottentomatoes.com/tv/perfect_crown
# https://www.rottentomatoes.com/tv/tracker_2023
# https://www.rottentomatoes.com/tv/monarch_legacy_of_monsters
# https://www.rottentomatoes.com/tv/the_house_of_the_spirits
# https://www.rottentomatoes.com/tv/trust_me_the_false_prophet
# https://www.rottentomatoes.com/tv/fallout
# https://www.rottentomatoes.com/tv/la_brea
# https://www.rottentomatoes.com/tv/sullivans_crossing
# https://www.rottentomatoes.com/tv/song_of_the_samurai
# https://www.rottentomatoes.com/tv/dark_winds
# https://www.rottentomatoes.com/tv/greys_anatomy
# https://www.rottentomatoes.com/tv/chernobyl
# https://www.rottentomatoes.com/tv/the_audacity
# https://www.rottentomatoes.com/tv/criminal_record
# https://www.rottentomatoes.com/tv/leaving_neverland
# https://www.rottentomatoes.com/tv/the_fall_and_rise_of_reggie_dinkins
# https://www.rottentomatoes.com/tv/the_witcher
# https://www.rottentomatoes.com/tv/reacher
# https://www.rottentomatoes.com/tv/unfamiliar
# https://www.rottentomatoes.com/tv/andor
# https://www.rottentomatoes.com/tv/scarpetta
# https://www.rottentomatoes.com/tv/bait
# https://www.rottentomatoes.com/tv/ponies
# https://www.rottentomatoes.com/tv/jo_nesbos_detective_hole
# https://www.rottentomatoes.com/tv/hijack
# https://www.rottentomatoes.com/tv/nemesis
# https://www.rottentomatoes.com/tv/the_hunting_party
# https://www.rottentomatoes.com/tv/between_father_and_son
# https://www.rottentomatoes.com/tv/bloodhounds
# https://www.rottentomatoes.com/tv/central_intelligence_the_agency
# https://www.rottentomatoes.com/tv/the_family_next_door
# https://www.rottentomatoes.com/tv/money_heist
# https://www.rottentomatoes.com/tv/straight_to_hell
# https://www.rottentomatoes.com/tv/bridgerton
# https://www.rottentomatoes.com/tv/jury_duty
# https://www.rottentomatoes.com/tv/unconditional
# https://www.rottentomatoes.com/tv/the_count_of_monte_cristo_2024
# https://www.rottentomatoes.com/tv/fake_profile
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 36
#      32 print(f"\nTotal de series encontradas: {len(all_series_urls)}")
#      33 for u in all_series_urls:
#      34     print(u)
#      35
# ---> 36 with open(DATA_DIR / "series_urls_pages.pkl", "wb") as f:
#      37     pickle.dump(all_series_urls, f)
#
# NameError: name 'DATA_DIR' is not defined

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import pickle
import time



url_search = [
    "https://www.rottentomatoes.com/browse/tv_series_browse/?page="
]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36"
}

all_series_urls = []

# for url in range(0, len(url_search)):
for page in range(1, 5):  # 1 hasta 11
    url = f"https://www.rottentomatoes.com/browse/tv_series_browse/?page={page}"
    # print(f"Scrapeando página {page}: {url}")

    resp = requests.get(url, headers=headers, timeout=10)

    if resp.status_code != 200:
        print(f"Error en página {page}: HTTP {resp.status_code}")
        continue

    soup = BeautifulSoup(resp.content, "html.parser")

    for a in soup.find_all("a", href=True):
        full_url = urljoin(url, a["href"])

        if "rottentomatoes.com/tv/" in full_url:
            all_series_urls.append(full_url)

    time.sleep(1)  # pausa pequeña para no saturar la página

# Quitar duplicados
all_series_urls = list(dict.fromkeys(all_series_urls))

print(f"\nTotal de series encontradas: {len(all_series_urls)}")

for u in all_series_urls:
    print(u)


with open("series_urls_pages.pkl", "wb") as f:
    pickle.dump(all_series_urls, f)

# with open("series_urls_pages.json", "w", encoding="utf-8") as f:
#     json.dump(all_series_urls, f, indent=4, ensure_ascii=False)
###### Si ya esta guardado como JSON
# with open("series_urls_pages.json", "r", encoding="utf-8") as f:
#     all_series_urls = json.load(f)

# with open("series_urls_pages.pkl", "wb") as f:
    # pickle.dump(all_series_urls, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 20
#      16 all_series_urls = []
#      17
#      18 for url in range(0, len(url_search)):
#      19     for page in range(1, 5):  # 1 hasta 11
# ---> 20         url = f"{url_search[url]}={page}"
#      21         # print(f"Scrapeando página {page}: {url}")
#      22
#      23         resp = requests.get(url, headers=headers, timeout=10)
#
# TypeError: list indices must be integers or slices, not str

# %%
# Path for files pkl wich are smaller than JSON files
# This File will contain the dataset of Series
pickle_path = DATA_DIR / "series_urls.pkl"

# %% [markdown]
# # Function to take all the values from many URLS

# %%
import requests
from bs4 import BeautifulSoup
import json
from urllib.parse import urljoin
import pandas as pd
import time


# "User-Agent" REQUEST simula que la petición como si viniera desde un navegador Chrome en Windows para evitar bloqueos de HTML
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36"
}



###########################    DEFINICIÓN DE MI FUNCIÓN PARA CADA URL    ###########################
def scrape_movie(url):
    resp = requests.get(url, headers=headers, timeout=10) ## Uso de el agente para hacer la solicitud como si viniera del navegador

    if resp.status_code != 200:
        print(f"Error HTTP {resp.status_code}: {url}")
        return None

    soup = BeautifulSoup(resp.content, "html.parser")

    # Título 
    title = None
    h1 = soup.find("h1")

    if h1:
        title = h1.get_text(strip=True)
    else:
        og = soup.find("meta", property="og:title")
        if og and og.get("content"):
            title = og["content"]

####################### 0. DETERMINE CONTENT TYPE (Movie or TV Show)

    if "rottentomatoes.com/m/" in url:
        content_type = "Movie"
    elif "rottentomatoes.com/tv/" in url:
        content_type = "TV Show"
    else:
        content_type = "Unknown"

####################### 1 . CALLING GENRE(S) 

    genre = None # create the variable

    script = soup.find("script", id="mps-page-integration")

    if script:
        script_text = script.get_text()

        match = re.search(r'"cag\[genre\]":"([^"]+)"', script_text) #Looking for the text

        if match:
            genre = match.group(1)
    
    genres = [] #Save genres

    if genre:
        genres = genre.split("|") # Spplit them 

    # print("Genre:", genre)
    
################# 2. CALLING: Summary, Tomatometer, Popcornmeter

     # Variables 
    summary = None
    tomatometer = None
    popcornmeter = None

    script = soup.find("script", id="media-scorecard-json")

    if script:
        try:
            data = json.loads(script.get_text(strip=True))
            
            #Checking for texts, different forms to get the values
            summary = data.get("description")
            tomatometer = data.get("criticsScore", {}).get("scorePercent")
            popcornmeter = data.get("audienceScore", {}).get("scorePercent")

        except json.JSONDecodeError:
            pass

 ############### 3. STREAM PLATFORMS 
    platform_names = []

    for li in soup.find_all("li", attrs={"data-qa": "movies-at-home-item"}):
        a = li.find("a", href=True)

        if a and "affiliates:" in a["href"]:
            name = a.get_text(strip=True)
            platform_names.append(name)

    platform_names = list(dict.fromkeys(platform_names))

############### 4. CRITICS CONSENSUS
    critics_consensus = None

    consensus_div = soup.find("div", id="critics-consensus")

    if consensus_div:
        p = consensus_div.find("p")
        if p:
            critics_consensus = p.get_text(" ", strip=True)

    movie_row = {
        "title": title,
        "content_type": content_type,
        "genre": genre,
        "url": url,
        "tomatometer": tomatometer,
        "popcornmeter": popcornmeter,
        "summary": summary,
        "critics_consensus": critics_consensus,
        "platforms": ", ".join(platform_names)
    }

    return movie_row ## Me retorna el valor de cada columna nueva


################################# Fin de la función ######################

# %%
#Cargo mi archivo pkl ### MAS ADELANTE SE ACTUALIZA CON TODAS LAS SERIES Y PEL[ICULAS]
with pickle_path.open("rb") as f:
    all_series_urls = pickle.load(f)

# %%
#####  For para crear la matriz
rows = []

for i, url in enumerate(all_series_urls, start=1):
    # print(f"Scrapeando {i}/{len(movie_urls)}: {url}")

    movie_row = scrape_movie(url)

    if movie_row is not None:
        rows.append(movie_row)

    time.sleep(1)


#### Creación del DataFrame 
df = pd.DataFrame(rows)



#### Guardar EL dataframe
df.to_csv("rottentomatoes_series_dataset.csv", index=False, encoding="utf-8")

df.head()
